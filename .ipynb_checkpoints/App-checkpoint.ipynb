# %%
"""@package docstring
Documentation for this module.
 
Importing the import libraries
"""
from tkinter import * 
import os

# %%
def show_frame(frame):
    """
    Creating a function that raises a frame when it is called
    """
    frame.tkraise()

# %%
"""
Creating the main window that holds all of the frames
"""
window = Tk()
window.title('Analyzing Clusters')
window.geometry('5000x5000')
window.state('zoomed')

window.rowconfigure(0, weight=1)
window.columnconfigure(0, weight=1)


"""
Creating all the frames that will be used in this app
"""
frame1 = Frame(window)
frame2 = Frame(window)
lgcframe = Frame(window)

"""
The frames concerning DBCSCAN
"""
dbframe = Frame(window)
dbframe_2007 = Frame(window)
dbframe_2008 = Frame(window)
dbframe_2009 = Frame(window)
dbframe_2010 = Frame(window)
dbframe_2011 = Frame(window)
dbframe_2012 = Frame(window)
dbframe_2013 = Frame(window)
dbframe_2014 = Frame(window)
dbframe_2015 = Frame(window)
dbframe_2016 = Frame(window)
dbstats1 = Frame(window)
dbstats2 = Frame(window)
dbstats3 = Frame(window)
dbstats4 = Frame(window)
dbstats5 = Frame(window)
dbstats6 = Frame(window)
dbstats7 = Frame(window)
dbstats8 = Frame(window)
dbstats9 = Frame(window)
dbstats10 = Frame(window)


"""
The frames concerning NetworkX
"""
networkframe = Frame(window)
frame_2007 = Frame(window)
frame_2008 = Frame(window)
frame_2009 = Frame(window)
frame_2010 = Frame(window)
frame_2011 = Frame(window)
frame_2012 = Frame(window)
frame_2013 = Frame(window)
frame_2014 = Frame(window)
frame_2015 = Frame(window)
frame_2016 = Frame(window)

"""
Adding all of the frames using a for loop
"""
for frame in (frame1, frame2, lgcframe, networkframe, dbframe, frame_2007, frame_2008, frame_2009, frame_2010,
              frame_2011, frame_2012, frame_2013, frame_2014, frame_2015, frame_2016,
              dbframe_2007, dbframe_2008, dbframe_2009, dbframe_2010,
              dbframe_2011, dbframe_2012, dbframe_2013, dbframe_2014, dbframe_2015, dbframe_2016,
              dbstats1, dbstats2, dbstats3, dbstats4,
              dbstats5, dbstats6, dbstats7, dbstats8, dbstats9, dbstats10):

    frame.grid(row=0, column=0, sticky='nsew')

"""
Frame 1 (the main frame) code. 
This simply welcomes the user to the clustering analysis app.
It also uses an Enter button
"""
frame1_title = Label(frame1, text='Welcome to Clustering Analysis',font=("Arial Bold", 70))
frame1_title.place(x=200,y=100)

frame1_label = Label(frame1, text='Click Here to Enter!',font=("Arial", 30))
frame1_label.place(x=575,y=300)

frame1_btn = Button(frame1, text='Enter', command=lambda: show_frame(frame2),font=("Arial", 20))
frame1_btn.place(x=690,y=400)

"""
Frame 2  code. 
This allows the user to pick a topic (LGC models, NetowkrX, or DBSCAN)
It also uses an Back button
"""
frame2_title = Label(frame2, text='Choose a Topic to Explore', bg='orange',font=("Arial", 30))
frame2_title.pack(fill='x')

frame2_btn = Button(frame2, text='LGC Model', command=lambda: show_frame(lgcframe),font=("Arial", 40))
frame2_btn.place(x=60,y=300)

frame2_btn = Button(frame2, text='NetworkX', command=lambda: show_frame(networkframe),font=("Arial", 40))
frame2_btn.place(x=650,y=300)

frame2_btn = Button(frame2, text='DBSCAN', command=lambda: show_frame(dbframe),font=("Arial", 40))
frame2_btn.place(x=1150,y=300)

frame2_btn = Button(frame2, text='Back', command=lambda: show_frame(frame1),font=("Arial", 20))
frame2_btn.pack()

"""
Latent Growth Curve model code. 
This frame shows the LGC model image.
It also uses an Back and Home button.
"""
lgcframe_title = Label(lgcframe, text='Latent Growth Curve Model', bg='yellow',font=("Arial", 30))
lgcframe_title.pack(fill='x')

lgccanvas = Canvas(lgcframe, width = 700, height = 700)
lgccanvas.pack()
lgcimg = PhotoImage(file="Photos/LGCModel.png")
lgccanvas.create_image(20,20, anchor=NW, image=lgcimg)

lgcframe_btn = Button(lgcframe, text='Back', command=lambda: show_frame(frame2),font=("Arial", 20))
lgcframe_btn.pack()

lgcframe_btn = Button(lgcframe, text='Home', command=lambda: show_frame(frame1),font=("Arial", 20))
lgcframe_btn.pack()


"""
DBSCAN Frame code.
This frame embedds all of the DBSCAN plots from 2007 - 2016.
The embedding allows the user to hover over the nodes
It also contains buttons that allows the user to see the specific statistics of that year
"""
dbframe_title = Label(dbframe, text='Click a Year to Get Started!', bg='purple',font=("Arial", 30))
dbframe_title.pack(fill='x')

dbframe_btn = Button(dbframe, text='Back', command=lambda: show_frame(frame2),font=("Arial", 20))
dbframe_btn.pack()

dbframe_btn = Button(dbframe, text='Home', command=lambda: show_frame(frame1),font=("Arial", 20))
dbframe_btn.pack()

"""
This section of the code creates the buttons for the years within the DBSCAN analysis
"""
yr7_btn = Button(dbframe, text='2007', command=lambda: show_frame(dbframe_2007),font=("Arial", 23))
yr7_btn.place(x=300,y=200)
yr8_btn = Button(dbframe, text='2008', command=lambda: show_frame(dbframe_2008),font=("Arial", 23))
yr8_btn.place(x=500,y=200)
yr9_btn = Button(dbframe, text='2009', command=lambda: show_frame(dbframe_2009),font=("Arial", 23))
yr9_btn.place(x=700,y=200)
yr10_btn = Button(dbframe, text='2010', command=lambda: show_frame(dbframe_2010),font=("Arial", 23))
yr10_btn.place(x=900,y=200)
yr11_btn = Button(dbframe, text='2011', command=lambda: show_frame(dbframe_2011),font=("Arial", 23))
yr11_btn.place(x=1100,y=200)
yr12_btn = Button(dbframe, text='2012', command=lambda: show_frame(dbframe_2012),font=("Arial", 23))
yr12_btn.place(x=300,y=300)
yr13_btn = Button(dbframe, text='2013', command=lambda: show_frame(dbframe_2013),font=("Arial", 23))
yr13_btn.place(x=500,y=300)
yr14_btn = Button(dbframe, text='2014', command=lambda: show_frame(dbframe_2014),font=("Arial", 23))
yr14_btn.place(x=700,y=300)
yr15_btn = Button(dbframe, text='2015', command=lambda: show_frame(dbframe_2015),font=("Arial", 23))
yr15_btn.place(x=900,y=300)
yr16_btn = Button(dbframe, text='2016', command=lambda: show_frame(dbframe_2016),font=("Arial", 23))
yr16_btn.place(x=1100,y=300)

"""
The following the the frame is for the 2007 DBSCAN graph
"""
dbframe_2007_title = Label(dbframe_2007, text='2007 DBSCAN Graph', bg='purple')
dbframe_2007_title.pack(fill='x')

dbimg2007 = PhotoImage(file="Photos/dbplot07.png")
dbimg7 = Label(dbframe_2007, image=dbimg2007)
dbimg7.place(x=250, y=50)

dbframe_2007_btn = Button(dbframe_2007, text='Home', command=lambda: show_frame(dbframe))
dbframe_2007_btn.pack()

dbo7_o8_btn = Button(dbframe_2007, text='Next Year', command=lambda: show_frame(dbframe_2008))
dbo7_o8_btn.place(x=1300,y=500)

"""
The following the the frame is for the 2008 DBSCAN graph
"""
dbframe_2008_title = Label(dbframe_2008, text='2008 DBSCAN Graph', bg='purple')
dbframe_2008_title.pack(fill='x')

dbimg2008 = PhotoImage(file="Photos/dbplot08.png")
dbimg8 = Label(dbframe_2008, image=dbimg2008)
dbimg8.place(x=250, y=50)

dbframe_2008_btn = Button(dbframe_2008, text='Home', command=lambda: show_frame(dbframe))
dbframe_2008_btn.pack()


dbo8_o7_btn = Button(dbframe_2008, text='Previous Year', command=lambda: show_frame(dbframe_2007))
dbo8_o7_btn.place(x=100,y=500)

dbo8_o9_btn = Button(dbframe_2008, text='Next Year', command=lambda: show_frame(dbframe_2009))
dbo8_o9_btn.place(x=1300,y=500)

"""
The following the the frame is for the 2009 DBSCAN graph
"""
dbframe_2009_title = Label(dbframe_2009, text='2009 DBSCAN Graph', bg='purple')
dbframe_2009_title.pack(fill='x')

dbimg2009 = PhotoImage(file="Photos/dbplot09.png")
dbimg9 = Label(dbframe_2009, image=dbimg2009)
dbimg9.place(x=250, y=50)

dbframe_2009_btn = Button(dbframe_2009, text='Home', command=lambda: show_frame(dbframe))
dbframe_2009_btn.pack()


dbo9_o8_btn = Button(dbframe_2009, text='Previous Year', command=lambda: show_frame(dbframe_2008))
dbo9_o8_btn.place(x=100,y=500)

dbo9_o10_btn = Button(dbframe_2009, text='Next Year', command=lambda: show_frame(dbframe_2010))
dbo9_o10_btn.place(x=1300,y=500)

"""
The following the the frame is for the 2010 DBSCAN graph
"""
dbframe_2010_title = Label(dbframe_2010, text='2010 DBSCAN Graph', bg='purple')
dbframe_2010_title.pack(fill='x')

dbimg2010 = PhotoImage(file="Photos/dbplot10.png")
dbimg10 = Label(dbframe_2010, image=dbimg2010)
dbimg10.place(x=250, y=50)

dbframe_2010_btn = Button(dbframe_2010, text='Home', command=lambda: show_frame(dbframe))
dbframe_2010_btn.pack()


dbo10_o9_btn = Button(dbframe_2010, text='Previous Year', command=lambda: show_frame(dbframe_2009))
dbo10_o9_btn.place(x=100,y=500)

dbo10_o11_btn = Button(dbframe_2010, text='Next Year', command=lambda: show_frame(dbframe_2011))
dbo10_o11_btn.place(x=1300,y=500)

"""
The following the the frame is for the 2011 DBSCAN graph
"""
dbframe_2011_title = Label(dbframe_2011, text='2011 DBSCAN Graph', bg='purple')
dbframe_2011_title.pack(fill='x')

dbimg2011 = PhotoImage(file="Photos/dbplot11.png")
dbimg11 = Label(dbframe_2011, image=dbimg2011)
dbimg11.place(x=250, y=50)

dbframe_2011_btn = Button(dbframe_2011, text='Home', command=lambda: show_frame(dbframe))
dbframe_2011_btn.pack()


dbo11_o10_btn = Button(dbframe_2011, text='Previous Year', command=lambda: show_frame(dbframe_2010))
dbo11_o10_btn.place(x=100,y=500)

dbo11_o12_btn = Button(dbframe_2011, text='Next Year', command=lambda: show_frame(dbframe_2012))
dbo11_o12_btn.place(x=1300,y=500)

"""
The following the the frame is for the 2012 DBSCAN graph
"""
dbframe_2012_title = Label(dbframe_2012, text='2012 DBSCAN Graph', bg='purple')
dbframe_2012_title.pack(fill='x')

dbimg2012 = PhotoImage(file="Photos/dbplot12.png")
dbimg12 = Label(dbframe_2012, image=dbimg2012)
dbimg12.place(x=250, y=50)

dbframe_2012_btn = Button(dbframe_2012, text='Home', command=lambda: show_frame(dbframe))
dbframe_2012_btn.pack()


dbo12_o11_btn = Button(dbframe_2012, text='Previous Year', command=lambda: show_frame(dbframe_2011))
dbo12_o11_btn.place(x=100,y=500)

dbo12_o13_btn = Button(dbframe_2012, text='Next Year', command=lambda: show_frame(dbframe_2013))
dbo12_o13_btn.place(x=1300,y=500)

"""
The following the the frame is for the 2013 DBSCAN graph
"""
dbframe_2013_title = Label(dbframe_2013, text='2013 DBSCAN Graph', bg='purple')
dbframe_2013_title.pack(fill='x')

dbimg2013 = PhotoImage(file="Photos/dbplot13.png")
dbimg13 = Label(dbframe_2013, image=dbimg2013)
dbimg13.place(x=250, y=50)

dbframe_2013_btn = Button(dbframe_2013, text='Home', command=lambda: show_frame(dbframe))
dbframe_2013_btn.pack()


dbo13_o12_btn = Button(dbframe_2013, text='Previous Year', command=lambda: show_frame(dbframe_2012))
dbo13_o12_btn.place(x=100,y=500)

dbo13_o14_btn = Button(dbframe_2013, text='Next Year', command=lambda: show_frame(dbframe_2014))
dbo13_o14_btn.place(x=1300,y=500)

"""
The following the the frame is for the 2014 DBSCAN graph
"""
dbframe_2014_title = Label(dbframe_2014, text='2014 DBSCAN Graph', bg='purple')
dbframe_2014_title.pack(fill='x')

dbimg2014 = PhotoImage(file="Photos/dbplot14.png")
dbimg14 = Label(dbframe_2014, image=dbimg2014)
dbimg14.place(x=250, y=50)

dbframe_2014_btn = Button(dbframe_2014, text='Home', command=lambda: show_frame(dbframe))
dbframe_2014_btn.pack()


dbo14_o13_btn = Button(dbframe_2014, text='Previous Year', command=lambda: show_frame(dbframe_2013))
dbo14_o13_btn.place(x=100,y=500)

dbo14_o15_btn = Button(dbframe_2014, text='Next Year', command=lambda: show_frame(dbframe_2015))
dbo14_o15_btn.place(x=1300,y=500)
"""
The following the the frame is for the 2015 DBSCAN graph
"""
dbframe_2015_title = Label(dbframe_2015, text='2015 DBSCAN Graph', bg='purple')
dbframe_2015_title.pack(fill='x')

dbimg2015 = PhotoImage(file="Photos/dbplot15.png")
dbimg15 = Label(dbframe_2015, image=dbimg2015)
dbimg15.place(x=250, y=50)

dbframe_2015_btn = Button(dbframe_2015, text='Home', command=lambda: show_frame(dbframe))
dbframe_2015_btn.pack()


dbo15_o14_btn = Button(dbframe_2015, text='Previous Year', command=lambda: show_frame(dbframe_2014))
dbo15_o14_btn.place(x=100,y=500)

dbo15_o16_btn = Button(dbframe_2015, text='Next Year', command=lambda: show_frame(dbframe_2016))
dbo15_o16_btn.place(x=1300,y=500)
"""
The following the the frame is for the 2016 DBSCAN graph
"""
dbframe_2016_title = Label(dbframe_2016, text='2016 DBSCAN Graph', bg='purple')
dbframe_2016_title.pack(fill='x')

dbimg2016 = PhotoImage(file="Photos/dbplot16.png")
dbimg16 = Label(dbframe_2016, image=dbimg2016)
dbimg16.place(x=250, y=50)

dbframe_2016_btn = Button(dbframe_2016, text='Home', command=lambda: show_frame(dbframe))
dbframe_2016_btn.pack()


dbo16_o15_btn = Button(dbframe_2016, text='Previous Year', command=lambda: show_frame(dbframe_2015))
dbo16_o15_btn.place(x=100,y=500)


"""
The following code creates the buttons to lead the user to the statistics
"""
db1_btn = Button(dbframe_2007, text='2007 Statistics', command=lambda: show_frame(dbstats1),font=("Arial", 23))
db1_btn.place(x=100,y=100)

db2_btn = Button(dbframe_2008, text='2008 Statistics', command=lambda: show_frame(dbstats2),font=("Arial", 23))
db2_btn.place(x=100,y=100)

db3_btn = Button(dbframe_2009, text='2009 Statistics', command=lambda: show_frame(dbstats3),font=("Arial", 23))
db3_btn.place(x=100,y=100)

db4_btn = Button(dbframe_2010, text='2010 Statistics', command=lambda: show_frame(dbstats4),font=("Arial", 23))
db4_btn.place(x=100,y=100)

db5_btn = Button(dbframe_2011, text='2011 Statistics', command=lambda: show_frame(dbstats5),font=("Arial", 23))
db5_btn.place(x=100,y=100)

db6_btn = Button(dbframe_2012, text='2012 Statistics', command=lambda: show_frame(dbstats6),font=("Arial", 23))
db6_btn.place(x=100,y=100)

db7_btn = Button(dbframe_2013, text='2013 Statistics', command=lambda: show_frame(dbstats7),font=("Arial", 23))
db7_btn.place(x=100,y=100)

db8_btn = Button(dbframe_2014, text='2014 Statistics', command=lambda: show_frame(dbstats8),font=("Arial", 23))
db8_btn.place(x=100,y=100)

db9_btn = Button(dbframe_2015, text='2015 Statistics', command=lambda: show_frame(dbstats9),font=("Arial", 23))
db9_btn.place(x=100,y=100)

db10_btn = Button(dbframe_2016, text='2016 Statistics', command=lambda: show_frame(dbstats10),font=("Arial", 23))
db10_btn.place(x=100,y=100)


"""
The following the the frame is for the 2007 DBSCAN stats
"""
dbstats_2007_title = Label(dbstats1, text='2007 DBSCAN stats', bg='purple')
dbstats_2007_title.pack(fill='x')

db2007 = PhotoImage(file="Photos/dbscan07.png")
dbim7 = Label(dbstats1, image=db2007)
dbim7.place(x=430, y=100)

dbstats_2007_btn = Button(dbstats1, text='Back', command=lambda: show_frame(dbframe_2007))
dbstats_2007_btn.pack()


"""
The following the the frame is for the 2008 DBSCAN stats
"""
dbstats_2008_title = Label(dbstats2, text='2008 DBSCAN stats', bg='purple')
dbstats_2008_title.pack(fill='x')

db2008 = PhotoImage(file="Photos/dbscan08.png")
dbim8 = Label(dbstats2, image=db2008)
dbim8.place(x=430, y=100)

dbstats_2008_btn = Button(dbstats2, text='Back', command=lambda: show_frame(dbframe_2008))
dbstats_2008_btn.pack()

"""
The following the the frame is for the 2009 DBSCAN stats
"""
dbstats_2009_title = Label(dbstats3, text='2009 DBSCAN stats', bg='purple')
dbstats_2009_title.pack(fill='x')

db2009 = PhotoImage(file="Photos/dbscan09.png")
dbim9 = Label(dbstats3, image=db2009)
dbim9.place(x=430, y=100)

dbstats_2009_btn = Button(dbstats3, text='Back', command=lambda: show_frame(dbframe_2009))
dbstats_2009_btn.pack()

"""
The following the the frame is for the 2010 DBSCAN stats
"""
dbstats_2010_title = Label(dbstats4, text='2010 DBSCAN stats', bg='purple')
dbstats_2010_title.pack(fill='x')

db2010 = PhotoImage(file="Photos/dbscan10.png")
dbim10 = Label(dbstats4, image=db2010)
dbim10.place(x=430, y=100)

dbstats_2010_btn = Button(dbstats4, text='Back', command=lambda: show_frame(dbframe_2010))
dbstats_2010_btn.pack()

"""
The following the the frame is for the 2011 DBSCAN stats
"""
dbstats_2011_title = Label(dbstats5, text='2011 DBSCAN stats', bg='purple')
dbstats_2011_title.pack(fill='x')

db2011 = PhotoImage(file="Photos/dbscan11.png")
dbim11 = Label(dbstats5, image=db2011)
dbim11.place(x=430, y=100)

dbstats_2011_btn = Button(dbstats5, text='Back', command=lambda: show_frame(dbframe_2011))
dbstats_2011_btn.pack()

"""
The following the the frame is for the 2012 DBSCAN stats
"""
dbstats_2012_title = Label(dbstats6, text='2012 DBSCAN stats', bg='purple')
dbstats_2012_title.pack(fill='x')

db2012 = PhotoImage(file="Photos/dbscan12.png")
dbim12 = Label(dbstats6, image=db2012)
dbim12.place(x=430, y=100)

dbstats_2008_btn = Button(dbstats6, text='Back', command=lambda: show_frame(dbframe_2012))
dbstats_2008_btn.pack()

"""
The following the the frame is for the 2013 DBSCAN stats
"""
dbstats_2013_title = Label(dbstats7, text='2013 DBSCAN stats', bg='purple')
dbstats_2013_title.pack(fill='x')

db2013 = PhotoImage(file="Photos/dbscan13.png")
dbim13 = Label(dbstats7, image=db2013)
dbim13.place(x=430, y=100)

dbstats_2013_btn = Button(dbstats7, text='Back', command=lambda: show_frame(dbframe_2013))
dbstats_2013_btn.pack()

"""
The following the the frame is for the 2014 DBSCAN stats
"""
dbstats_2014_title = Label(dbstats8, text='2014 DBSCAN stats', bg='purple')
dbstats_2014_title.pack(fill='x')

db2014 = PhotoImage(file="Photos/dbscan14.png")
dbim14 = Label(dbstats8, image=db2014)
dbim14.place(x=430, y=100)

dbstats_2014_btn = Button(dbstats8, text='Back', command=lambda: show_frame(dbframe_2014))
dbstats_2014_btn.pack()

"""
The following the the frame is for the 2015 DBSCAN stats
"""
dbstats_2015_title = Label(dbstats9, text='2015 DBSCAN stats', bg='purple')
dbstats_2015_title.pack(fill='x')

db2015 = PhotoImage(file="Photos/dbscan15.png")
dbim15 = Label(dbstats9, image=db2015)
dbim15.place(x=430, y=100)

dbstats_2015_btn = Button(dbstats9, text='Back', command=lambda: show_frame(dbframe_2015))
dbstats_2015_btn.pack()

"""
The following the the frame is for the 2016 DBSCAN stats
"""
dbstats_2016_title = Label(dbstats10, text='2016 DBSCAN stats', bg='purple')
dbstats_2016_title.pack(fill='x')

db2016 = PhotoImage(file="Photos/dbscan16.png")
dbim16 = Label(dbstats10, image=db2016)
dbim16.place(x=430, y=100)

dbstats_2016_btn = Button(dbstats10, text='Back', command=lambda: show_frame(dbframe_2016))
dbstats_2016_btn.pack()









"""
This section holds the code that creates the NetworkX frame
"""
networkframe_title = Label(networkframe, text='Click a Year to Get Started!', bg='blue',font=("Arial", 30))
networkframe_title.pack(fill='x')

networkframe_btn = Button(networkframe, text='Back', command=lambda: show_frame(frame2),font=("Arial", 20))
networkframe_btn.pack()

networkframe_btn = Button(networkframe, text='Home', command=lambda: show_frame(frame1),font=("Arial", 20))
networkframe_btn.pack()

"""
This section holds the code that crates the buttons for the years within the NetworkX analysis
"""

yr1_btn = Button(networkframe, text='2007', command=lambda: show_frame(frame_2007),font=("Arial", 23))
yr1_btn.place(x=300,y=200)
yr2_btn = Button(networkframe, text='2008', command=lambda: show_frame(frame_2008),font=("Arial", 23))
yr2_btn.place(x=500,y=200)
yr3_btn = Button(networkframe, text='2009', command=lambda: show_frame(frame_2009),font=("Arial", 23))
yr3_btn.place(x=700,y=200)
yr4_btn = Button(networkframe, text='2010', command=lambda: show_frame(frame_2010),font=("Arial", 23))
yr4_btn.place(x=900,y=200)
yr5_btn = Button(networkframe, text='2011', command=lambda: show_frame(frame_2011),font=("Arial", 23))
yr5_btn.place(x=1100,y=200)
yr6_btn = Button(networkframe, text='2012', command=lambda: show_frame(frame_2012),font=("Arial", 23))
yr6_btn.place(x=300,y=300)
yr7_btn = Button(networkframe, text='2013', command=lambda: show_frame(frame_2013),font=("Arial", 23))
yr7_btn.place(x=500,y=300)
yr8_btn = Button(networkframe, text='2014', command=lambda: show_frame(frame_2014),font=("Arial", 23))
yr8_btn.place(x=700,y=300)
yr9_btn = Button(networkframe, text='2015', command=lambda: show_frame(frame_2015),font=("Arial", 23))
yr9_btn.place(x=900,y=300)
yr10_btn = Button(networkframe, text='2016', command=lambda: show_frame(frame_2016),font=("Arial", 23))
yr10_btn.place(x=1100,y=300)

"""
The following the the frame is for the 2007 NetworkX graph
"""
frame_2007_title = Label(frame_2007, text='2007 NetworkX Graph', bg='yellow')
frame_2007_title.pack(fill='x')

img2007 = PhotoImage(file="Photos/output_0_1.png")
img7 = Label(frame_2007, image=img2007)
img7.place(x=430, y=100)

frame_2007_btn = Button(frame_2007, text='Home', command=lambda: show_frame(networkframe))
frame_2007_btn.pack()

o7_o8_btn = Button(frame_2007, text='Next Year', command=lambda: show_frame(frame_2008))
o7_o8_btn.place(x=1200,y=500)


"""
The following the the frame is for the 2008 NetworkX graph
"""
frame_2008_title = Label(frame_2008, text='2008 NetworkX Graph', bg='yellow')
frame_2008_title.pack(fill='x')

img2008 = PhotoImage(file="Photos/output_0_3.png")
img8 = Label(frame_2008, image=img2008)
img8.place(x=430, y=100)

frame_2008_btn = Button(frame_2008, text='Home', command=lambda: show_frame(networkframe))
frame_2008_btn.pack()

o8_o9_btn = Button(frame_2008, text='Next Year', command=lambda: show_frame(frame_2009))
o8_o9_btn.place(x=1200,y=500)

o8_o7_btn = Button(frame_2008, text='Previous Year', command=lambda: show_frame(frame_2007))
o8_o7_btn.place(x=100,y=500)

"""
The following the the frame is for the 2009 NetworkX graph
"""
frame_2009_title = Label(frame_2009, text='2009 NetworkX Graph', bg='yellow')
frame_2009_title.pack(fill='x')

img2009 = PhotoImage(file="Photos/output_0_5.png")
img9 = Label(frame_2009, image=img2009)
img9.place(x=430, y=100)

frame_2009_btn = Button(frame_2009, text='Home', command=lambda: show_frame(networkframe))
frame_2009_btn.pack()

o9_o10_btn = Button(frame_2009, text='Next Year', command=lambda: show_frame(frame_2010))
o9_o10_btn.place(x=1200,y=500)

o9_o8_btn = Button(frame_2009, text='Previous Year', command=lambda: show_frame(frame_2008))
o9_o8_btn.place(x=100,y=500)

"""
The following the the frame is for the 2010 NetworkX graph
"""
frame_2010_title = Label(frame_2010, text='2010 NetworkX Graph', bg='yellow')
frame_2010_title.pack(fill='x')

img2010 = PhotoImage(file="Photos/output_0_7.png")
img10 = Label(frame_2010, image=img2010)
img10.place(x=430, y=100)

frame_2010_btn = Button(frame_2010, text='Home', command=lambda: show_frame(networkframe))
frame_2010_btn.pack()

o10_o9_btn = Button(frame_2010, text='Next Year', command=lambda: show_frame(frame_2011))
o10_o9_btn.place(x=1200,y=500)

o10_o9_btn = Button(frame_2010, text='Previous Year', command=lambda: show_frame(frame_2009))
o10_o9_btn.place(x=100,y=500)

"""
The following the the frame is for the 2011 NetworkX graph
"""
frame_2011_title = Label(frame_2011, text='2011 NetworkX Graph', bg='yellow')
frame_2011_title.pack(fill='x')

img2011 = PhotoImage(file="Photos/output_0_9.png")
img11 = Label(frame_2011, image=img2011)
img11.place(x=430, y=100)

frame_2011_btn = Button(frame_2011, text='Home', command=lambda: show_frame(networkframe))
frame_2011_btn.pack()

o11_o12_btn = Button(frame_2011, text='Next Year', command=lambda: show_frame(frame_2012))
o11_o12_btn.place(x=1200,y=500)

o11_o10_btn = Button(frame_2011, text='Previous Year', command=lambda: show_frame(frame_2010))
o11_o10_btn.place(x=100,y=500)

"""
The following the the frame is for the 2012 NetworkX graph
"""
frame_2012_title = Label(frame_2012, text='2012 NetworkX Graph', bg='yellow')
frame_2012_title.pack(fill='x')

img2012 = PhotoImage(file="Photos/output_0_11.png")
img12 = Label(frame_2012, image=img2012)
img12.place(x=430, y=100)

frame_2012_btn = Button(frame_2012, text='Home', command=lambda: show_frame(networkframe))
frame_2012_btn.pack()

o12_o13_btn = Button(frame_2012, text='Next Year', command=lambda: show_frame(frame_2013))
o12_o13_btn.place(x=1200,y=500)

o12_o11_btn = Button(frame_2012, text='Previous Year', command=lambda: show_frame(frame_2011))
o12_o11_btn.place(x=100,y=500)

"""
The following the the frame is for the 2013 NetworkX graph
"""
frame_2013_title = Label(frame_2013, text='2013 NetworkX Graph', bg='yellow')
frame_2013_title.pack(fill='x')

img2013 = PhotoImage(file="Photos/output_0_13.png")
img13 = Label(frame_2013, image=img2013)
img13.place(x=430, y=100)

frame_2013_btn = Button(frame_2013, text='Home', command=lambda: show_frame(networkframe))
frame_2013_btn.pack()

o13_o14_btn = Button(frame_2013, text='Next Year', command=lambda: show_frame(frame_2014))
o13_o14_btn.place(x=1200,y=500)

o13_o12_btn = Button(frame_2013, text='Previous Year', command=lambda: show_frame(frame_2012))
o13_o12_btn.place(x=100,y=500)

"""
The following the the frame is for the 2014 NetworkX graph
"""
frame_2014_title = Label(frame_2014, text='2014 NetworkX Graph', bg='yellow')
frame_2014_title.pack(fill='x')

img2014 = PhotoImage(file="Photos/output_0_15.png")
img14 = Label(frame_2014, image=img2014)
img14.place(x=430, y=100)

frame_2014_btn = Button(frame_2014, text='Home', command=lambda: show_frame(networkframe))
frame_2014_btn.pack()

o14_o15_btn = Button(frame_2014, text='Next Year', command=lambda: show_frame(frame_2015))
o14_o15_btn.place(x=1200,y=500)

o14_o13_btn = Button(frame_2014, text='Previous Year', command=lambda: show_frame(frame_2013))
o14_o13_btn.place(x=100,y=500)

"""
The following the the frame is for the 2015 NetworkX graph
"""
frame_2015_title = Label(frame_2015, text='2015 NetworkX Graph', bg='yellow')
frame_2015_title.pack(fill='x')

img2015 = PhotoImage(file="Photos/output_0_17.png")
img15 = Label(frame_2015, image=img2015)
img15.place(x=430, y=100)

frame_2015_btn = Button(frame_2015, text='Home', command=lambda: show_frame(networkframe))
frame_2015_btn.pack()

o15_o16_btn = Button(frame_2015, text='Next Year', command=lambda: show_frame(frame_2016))
o15_o16_btn.place(x=1200,y=500)

o15_o14_btn = Button(frame_2015, text='Previous Year', command=lambda: show_frame(frame_2014))
o15_o14_btn.place(x=100,y=500)
"""
The following the the frame is for the 2016 NetworkX graph
"""
frame_2016_title = Label(frame_2016, text='2016 NetworkX Graph', bg='yellow')
frame_2016_title.pack(fill='x')

img2016 = PhotoImage(file="Photos/output_0_19.png")
img16 = Label(frame_2016, image=img2016)
img16.place(x=430, y=100)

frame_2016_btn = Button(frame_2016, text='Home', command=lambda: show_frame(networkframe))
frame_2016_btn.pack()


o16_o15_btn = Button(frame_2016, text='Previous Year', command=lambda: show_frame(frame_2015))
o16_o15_btn.place(x=100,y=500)



"""
The following code shows frame 1 and allows the main window to run
"""
show_frame(frame1)
window.mainloop()
